# %% [markdown]
# #### Daemon

# %%
from config import DumpSightConfig
from tools.events import monitor_core

config = DumpSightConfig()
monitor_core(config)
# Out:
# Core dump detected: core.30182, PID: 30182
# Core dump detected: core.30330, PID: 30330
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 from tools.events import monitor_core
#       4 config = DumpSightConfig()
# ----> 5 monitor_core(config)
#
# File /workspace/DPDK/tools/events.py:15, in monitor_core(config)
#      13 try:
#      14     while True:
# ---> 15         for event in inotify.read():
#      16             filename = event.name
#      17             if (
#      18                 not filename.startswith("core")
#      19                 or filename.endswith(".meta.json")
#      20                 or filename.endswith(".context.json")
#      21             ):
#
# File /opt/conda/envs/dpdk/lib/python3.10/site-packages/inotify_simple.py:137, in INotify.read(self, timeout, read_delay)
# ...
