# %%
from agent.graphs.fault_analysis.graph import get_fault_analysis_graph


client_id = "123"
pid = "1783587"
timestamp = 1775568607.873688

graph = get_fault_analysis_graph()

crash_report = graph.invoke(
    {
        "client_id": client_id,
        "pid": pid,
        "timestamp": timestamp,
        "mode": "fault_analysis",
    },
    durability=None,
)

# %%
print(1)
